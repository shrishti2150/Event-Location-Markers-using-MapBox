# %%
import requests

response = requests.get(
    url="https://api.predicthq.com/v1/events/",
    headers={"Authorization": "Bearer lE8MKO7-JLI3VUUK8JgHieVSYNfQ1y-4VeD_SM8i",
            "Accept": "application/json",
             
            },
    params= {"country": "AE"}
)


print(response.json())
# Out:
# {'count': 5000, 'overflow': True, 'next': 'https://api.predicthq.com/v1/events/?country=AE&limit=10&offset=10', 'previous': None, 'results': [{'relevance': 0.0, 'id': '5BRoo9DqydX5BP8BBp', 'title': 'UOWD - Open Day', 'description': 'Open Day - UOWD', 'category': 'conferences', 'labels': ['conference', 'education', 'family'], 'rank': 0, 'local_rank': 0, 'aviation_rank': None, 'phq_attendance': None, 'entities': [{'type': 'venue', 'name': 'University of Wollongong in Dubai', 'formatted_address': 'Block 5, 14 & 15 Dubai Knowledge Park\nDubai\nDubayy\nUnited Arab Emirates', 'entity_id': '39yvTcR7GSuHtxaCBDveJBU'}], 'duration': 10800, 'start': '2021-11-27T15:00:00Z', 'end': '2021-11-27T18:00:00Z', 'updated': '2021-10-27T12:26:25Z', 'first_seen': '2021-10-27T12:22:52Z', 'timezone': 'Asia/Dubai', 'location': [55.1628301, 25.101547], 'geo': {'geometry': {'type': 'Point', 'coordinates': [55.1628301, 25.101547]}}, 'scope': 'locality', 'country': 'AE', 'place_hierarchies': [['6295630', '6255147
# ...

# %%
j=response.json()
#j['results']

# %%
#! usr/bin/env python

from sys import argv
from os.path import exists
import simplejson as json 

script, in_file, out_file = argv

data = j['results']

geojson = {
    "type": "FeatureCollection",
    "features": [
    {
        "type": "Feature",
        "geometry" : {
            "type": "Point",
            "coordinates": [d["location"][0], d["location"][1]],
            },
        "properties" : d,
     } for d in data]
}


output = open(out_file, 'w')
json.dump(geojson, output)

print (geojson)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [55.1628301, 25.101547]}, 'properties': {'relevance': 0.0, 'id': '5BRoo9DqydX5BP8BBp', 'title': 'UOWD - Open Day', 'description': 'Open Day - UOWD', 'category': 'conferences', 'labels': ['conference', 'education', 'family'], 'rank': 0, 'local_rank': 0, 'aviation_rank': None, 'phq_attendance': None, 'entities': [{'type': 'venue', 'name': 'University of Wollongong in Dubai', 'formatted_address': 'Block 5, 14 & 15 Dubai Knowledge Park\nDubai\nDubayy\nUnited Arab Emirates', 'entity_id': '39yvTcR7GSuHtxaCBDveJBU'}], 'duration': 10800, 'start': '2021-11-27T15:00:00Z', 'end': '2021-11-27T18:00:00Z', 'updated': '2021-10-27T12:26:25Z', 'first_seen': '2021-10-27T12:22:52Z', 'timezone': 'Asia/Dubai', 'location': [55.1628301, 25.101547], 'geo': {'geometry': {'type': 'Point', 'coordinates': [55.1628301, 25.101547]}}, 'scope': 'locality', 'country': 'AE', 'place_hierarchies': [['6295630', '6
# ...

# %%
import json
with open('geo.geojson', 'w') as outfile:
    json.dump(geojson, outfile)

# %%
import json
with open('data.txt', 'w') as outfile:
    json.dump(response.json(), outfile)

# %%
import pandas as pd
df=pd.read_json('data.txt')

# %%
df1=df['results']
df1
# Out:
# 0    {'relevance': 0.0, 'id': '5BRoo9DqydX5BP8BBp',...
# 1    {'relevance': 0.0, 'id': '6oNvZ3yqoBGxJc6DYg',...
# 2    {'relevance': 0.0, 'id': 'Fr6cxqjJ2gXbdwd7XN',...
# 3    {'relevance': 0.0, 'id': '6xkF8DGEMxntjHfD3A',...
# 4    {'relevance': 0.0, 'id': 'EHtgXhwFzyyNfETtSK',...
# 5    {'relevance': 0.0, 'id': 'CG4Uenmw2TeTpXetSf',...
# 6    {'relevance': 0.0, 'id': '7pm7X43niSBoziLVou',...
# 7    {'relevance': 0.0, 'id': 'ym5e2UVkLTtmL6AJ9w',...
# 8    {'relevance': 0.0, 'id': 'HjSb8PcTkyZniGQEFy',...
# 9    {'relevance': 0.0, 'id': '4EKeW6ynZWeq3soXGe',...
# Name: results, dtype: object

# %%
for data in df1:
    print (data)
# Out:
# {'relevance': 0.0, 'id': '5BRoo9DqydX5BP8BBp', 'title': 'UOWD - Open Day', 'description': 'Open Day - UOWD', 'category': 'conferences', 'labels': ['conference', 'education', 'family'], 'rank': 0, 'local_rank': 0, 'aviation_rank': None, 'phq_attendance': None, 'entities': [{'type': 'venue', 'name': 'University of Wollongong in Dubai', 'formatted_address': 'Block 5, 14 & 15 Dubai Knowledge Park\nDubai\nDubayy\nUnited Arab Emirates', 'entity_id': '39yvTcR7GSuHtxaCBDveJBU'}], 'duration': 10800, 'start': '2021-11-27T15:00:00Z', 'end': '2021-11-27T18:00:00Z', 'updated': '2021-10-27T12:26:25Z', 'first_seen': '2021-10-27T12:22:52Z', 'timezone': 'Asia/Dubai', 'location': [55.1628301, 25.101547], 'geo': {'geometry': {'type': 'Point', 'coordinates': [55.1628301, 25.101547]}}, 'scope': 'locality', 'country': 'AE', 'place_hierarchies': [['6295630', '6255147', '290557', '292224', '6691113'], ['6295630', '6255147', '290557', '292224', '292223']], 'state': 'active', 'brand_safe': True, 'private': Fa
# ...

# %%
#pd.DataFrame.from_dict(df1, orient='index').transpose() #A

df2=pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in df1.items() ])).transpose() #B (Better)
df2
# Out:
#   aviation_rank brand_safe     category country  \
# 0          None       True  conferences      AE
# 1             0       True       sports      AE
# 2             0       True       sports      AE
# 3             0       True       sports      AE
# 4             0       True       sports      AE
# 5          None       True        expos      AE
# 6          None       True    festivals      AE
# 7             0       True  conferences      AE
# 8          None       True  conferences      AE
# 9          None       True    festivals      AE
#
#                                          description duration  \
# 0                                    Open Day - UOWD    10800
# 1                                                           0
# 2                                                           0
# 3                                                           0
# 4                                                           0
# ...

# %%
for data in df2['geo']:
    print (data)
# Out:
# {'geometry': {'type': 'Point', 'coordinates': [55.1628301, 25.101547]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.4651618, 24.9947022]}}
# {'geometry': {'type': 'Point', 'coordinates': [56.171228885650635, 25.315176314099507]}}
# {'geometry': {'type': 'Point', 'coordinates': [56.26595377922058, 25.609294083605757]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.80047249794006, 25.70515764049144]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.1600651, 24.966401]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.2226377, 25.0351416]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.2888063, 25.2271847]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.2707828, 25.2048493]}}
# {'geometry': {'type': 'Point', 'coordinates': [55.3279045, 25.2281726]}}

# %%
df2=df2.drop(['aviation_rank','brand_safe','scope','rank','relevance','first_seen','local_rank','predicted_end','place_hierarchies','aviation_rank','phq_attendance','labels','id','geo'],axis=1)

# %%
df2.head()
# Out:
#       category country      description duration                   end  \
# 0  conferences      AE  Open Day - UOWD    10800  2021-11-27T18:00:00Z
# 1       sports      AE                         0  2021-11-27T12:40:00Z
# 2       sports      AE                         0  2021-11-27T12:40:00Z
# 3       sports      AE                         0  2021-11-27T12:35:00Z
# 4       sports      AE                         0  2021-11-27T12:35:00Z
#
#                                             entities  \
# 0  [{'type': 'venue', 'name': 'University of Woll...
# 1  [{'type': 'venue', 'name': 'The Sevens Stadium...
# 2  [{'type': 'venue', 'name': 'Masafi Stadium', '...
# 3  [{'type': 'venue', 'name': 'Dibba Al-Hisn Stad...
# 4  [{'type': 'venue', 'name': 'Al Jazirah Al Hamr...
#
#                                    location private                 start  \
# 0                   [55.1628301, 25.101547]   False  2021-11-27T15:00:00Z
# ...

# %%
df2.to_csv('Events1.csv')
